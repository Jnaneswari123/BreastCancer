# %% [markdown]
# Breast Cancer Wisconsin (Diagnostic) using ANN Algorithm by TensorFlow

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# IMPORT LIBRARIES

# %%
# import liberaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# TO READ THE DATASET

# %%
df=pd.read_csv("breast-cancer-wisconsin.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.shape
# Out:
# (569, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %% [markdown]
# DROP ID AND NAMED COLUMNS

# %%
#remove Id and unnamed columns
df = df.drop(columns = ['id','Unnamed: 32'])
df.shape
# Out:
# (569, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
#  13  perimeter_se             569 non-null    float64
#  14  area_se                  569 non-null    float64
#  15  smoothness_se            569 non-null    float64
#  16  compactness_se           569 non-null    float64
#  17  concavity_se             569 non-null    float64
#  18  concave points_se        569 non-null    float64
#  19  symmetry_se              569 non-null    float64
#  20  fractal_dimension_se     569 non-null    float64
#  21  radius_worst             569 non-null    float64
#  22  texture_worst            569 non-null    float64
#  23  perimeter_worst          569 non-null    float64
#  24  area_worst               569 non-null    float64
#  25  smoothness_worst         569 non-null    float64
#  26  compactness_worst        569 non-null    float64
#  27  concavity_worst          569 non-null    float64
#  28  concave points_worst     569 non-null    float64
#  29  symmetry_worst           569 non-null    float64
#  30  fractal_dimension_worst  569 non-null    float64
# dtypes: float64(30), object(1)
# memory usage: 137.9+ KB

# %%
# new column for benign and malign
df.loc[df['diagnosis']=='M', 'benign_0__mal_1'] = 1
df.loc[df['diagnosis']=='B', 'benign_0__mal_1'] = 0
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0         0.2419  ...          17.33           184.60      2019.0
# 1         0.1812  ...          23.41           158.80      1956.0
# 2         0.2069  ...          25.53           152.50      1709.0
# 3         0.2597  ...          26.50            98.87       567.7
# 4         0.1809  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  benign_0__mal_1
# 0          0.4601                  0.11890              1.0
# 1          0.2750                  0.08902              1.0
# 2          0.3613                  0.08758              1.0
# 3          0.6638                  0.17300              1.0
# 4          0.2364                  0.07678              1.0
#
# [5 rows x 32 columns]

# %% [markdown]
# TO DROP THE DIAGNOSIS AS WE CREATED AN NEW COLUMN (benign_0__mal_1)

# %%
# drop Diagnosis
df = df.drop(columns = ['diagnosis'])
df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  benign_0__mal_1
# 0          0.4601                  0.11890              1.0
# 1          0.2750                  0.08902              1.0
# 2          0.3613                  0.08758              1.0
# 3          0.6638                  0.17300              1.0
# 4          0.2364                  0.07678              1.0
#
# [5 rows x 31 columns]

# %% [markdown]
# TO VISUALIZE

# %%
sns.countplot(x='benign_0__mal_1', data=df)
plt.show()

# %% [markdown]
# TO SEPEARATE INDEPENDENT AND DEPENDENT

# %%
# independent and dependent
X = df.drop(['benign_0__mal_1'], axis=1)
y = df['benign_0__mal_1']

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %% [markdown]
# SPLIT THE DATASET

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (455, 30)
# (114, 30)
# (455,)
# (114,)

# %% [markdown]
# TO SCALE THE DATASET

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# CREATE ANN WITH TENSORFLOW

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense

# %% [markdown]
# CREATE ANN

# %%
model = Sequential()
model.add(InputLayer(input_shape=(30,))) # input layer
model.add(Dense(units = 26, activation='relu')) # hidden layer 1
model.add(Dense(units = 15, activation='relu')) # hidden layer 2
model.add(Dense(units = 1, activation='sigmoid')) # output layer
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 26)                806
#
#  dense_1 (Dense)             (None, 15)                405
#
#  dense_2 (Dense)             (None, 1)                 16
#
# =================================================================
# Total params: 1227 (4.79 KB)
# Trainable params: 1227 (4.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# TRAIN MODEL

# %%
model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 18ms/step - loss: 0.6820 - accuracy: 0.6374 - val_loss: 0.6630 - val_accuracy: 0.5965
# Epoch 2/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6434 - accuracy: 0.7253 - val_loss: 0.6143 - val_accuracy: 0.7368
# Epoch 3/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5933 - accuracy: 0.8220 - val_loss: 0.5656 - val_accuracy: 0.7719
# Epoch 4/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.5381 - accuracy: 0.8615 - val_loss: 0.5085 - val_accuracy: 0.8509
# Epoch 5/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4768 - accuracy: 0.8835 - val_loss: 0.4546 - val_accuracy: 0.8596
# Epoch 6/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4152 - accuracy: 0.9055 - val_loss: 0.4003 - val_accuracy: 0.8947
# Epoch 7/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3615 - accuracy: 0.9209 - val_loss: 0.3573 - val_accuracy: 0.8860
# Epoch 8/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3141 - accuracy: 0.9253 - val_loss: 0.3227 - val_accuracy: 0.8860
# Epoch 9/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2759 - accuracy: 0.9209 - val_loss: 0.2971 - val_accuracy: 0.8947
# Epoch 10/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2454 - accuracy: 0.9319 - val_loss: 0.2743 - val_accuracy: 0.8860
# Epoch 11/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2207 - accuracy: 0.9341 - val_loss: 0.2620 - val_accuracy: 0.9035
# Epoch 12/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2021 - accuracy: 0.9297 - val_loss: 0.2439 - val_accuracy: 0.9211
# Epoch 13/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1863 - accuracy: 0.
# Epoch 58/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0470 - accuracy: 0.9824 - val_loss: 0.1537 - val_accuracy: 0.9561
# Epoch 59/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0465 - accuracy: 0.9824 - val_loss: 0.1427 - val_accuracy: 0.9474
# Epoch 60/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0461 - accuracy: 0.9890 - val_loss: 0.1537 - val_accuracy: 0.9561
# Epoch 61/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0437 - accuracy: 0.9824 - val_loss: 0.1429 - val_accuracy: 0.9474
# Epoch 62/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0439 - accuracy: 0.9846 - val_loss: 0.1482 - val_accuracy: 0.9474
# Epoch 63/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0439 - accuracy: 0.9846 - val_loss: 0.1437 - val_accuracy: 0.9474
# Epoch 64/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0433 - accuracy: 0.9824 - val_loss: 0.1503 - val_accuracy: 0.9561
# Epoch 65/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0434 - accuracy: 0.9868 - val_loss: 0.1468 - val_accuracy: 0.9561
# Epoch 66/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 0.9846 - val_loss: 0.1467 - val_accuracy: 0.9474
# Epoch 67/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0408 - accuracy: 0.9868 - val_loss: 0.1484 - val_accuracy: 0.9474
# Epoch 68/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 0.9846 - val_loss: 0.1477 - val_accuracy: 0.9474
# Epoch 69/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0421 - accuracy: 0.9890 - val_loss: 0.1465 - val_accuracy: 0.9561
# Epoch 70/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0488 - accuracy: 0.9846 - val_loss: 0.1405 - val_accuracy: 0.9474
# Epoch 71/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0413 - accuracy: 0.9824 - val_loss: 0.1508 - val_accuracy: 0.9649
# Epoch 72/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0387 - accuracy: 0.9868 - val_loss: 0.1457 - val_accuracy: 0.9474
# Epoch 73/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0402 - accuracy: 0.9846 - val_loss: 0.1529 - val_accuracy: 0.9561
# Epoch 74/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0382 - accuracy: 0.9846 - val_loss: 0.1540 - val_accuracy: 0.9649
# Epoch 75/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0378 - accuracy: 0.9890 - val_loss: 0.1487 - val_accuracy: 0.9474
# Epoch 76/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0366 - accuracy: 0.9846 - val_loss: 0.1448 - val_accuracy: 0.9474
# Epoch 77/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0373 - accuracy: 0.9868 - val_loss: 0.1485 - val_accuracy: 0.9474
# Epoch 78/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0355 - accuracy: 0.9868 - val_loss: 0.1468 - val_accuracy: 0.9474
# Epoch 79/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0364 - accuracy: 0.9890 - val_loss: 0.1505 - val_accuracy: 0.9474
# Epoch 80/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0342 - accuracy: 0.9868 - val_loss: 0.1476 - val_accuracy: 0.9474
# Epoch 81/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0346 - accuracy: 0.9890 - val_loss: 0.1486 - val_accuracy: 0.9474
# Epoch 82/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0347 - accuracy: 0.9890 - val_loss: 0.1497 - val_accuracy: 0.9649
# Epoch 83/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0345 - accuracy: 0.9890 - val_loss: 0.1481 - val_accuracy: 0.9561
# Epoch 84/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9890 - val_loss: 0.1463 - val_accuracy: 0.9474
# Epoch 85/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0352 - accuracy: 0.9846 - val_loss: 0.1471 - val_accuracy: 0.9561
# Epoch 86/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9912 - val_loss: 0.1460 - val_accuracy: 0.9561
# Epoch 87/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0350 - accuracy: 0.9934 - val_loss: 0.1507 - val_accuracy: 0.9561
# Epoch 88/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0355 - accuracy: 0.9846 - val_loss: 0.1483 - val_accuracy: 0.9561
# Epoch 89/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0346 - accuracy: 0.9912 - val_loss: 0.1522 - val_accuracy: 0.9649
# Epoch 90/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0378 - accuracy: 0.9868 - val_loss: 0.1452 - val_accuracy: 0.9561
# Epoch 91/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0307 - accuracy: 0.9912 - val_loss: 0.1532 - val_accuracy: 0.9649
# Epoch 92/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9912 - val_loss: 0.1502 - val_accuracy: 0.9561
# Epoch 93/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0303 - accuracy: 0.9890 - val_loss: 0.1525 - val_accuracy: 0.9561
# Epoch 94/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0310 - accuracy: 0.9912 - val_loss: 0.1521 - val_accuracy: 0.9561
# Epoch 95/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0295 - accuracy: 0.9912 - val_loss: 0.1516 - val_accuracy: 0.9561
# Epoch 96/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9934 - val_loss: 0.1520 - val_accuracy: 0.9561
# Epoch 97/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0289 - accuracy: 0.9912 - val_loss: 0.1488 - val_accuracy: 0.9561
# Epoch 98/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0284 - accuracy: 0.9912 - val_loss: 0.1489 - val_accuracy: 0.9561
# Epoch 99/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0280 - accuracy: 0.9956 - val_loss: 0.1508 - val_accuracy: 0.9561
# Epoch 100/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0297 - accuracy: 0.9890 - val_loss: 0.1504 - val_accuracy: 0.9561

# %% [markdown]
# TO LOOK AT THE PLOT FOR BETTER UNDERSTANDING

# %%
# plot train and test accuracy
import matplotlib.pyplot as plt
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
plt.show()

# %% [markdown]
# EARLY STOP - to monitor the validate loss
# patience - to wait until the loss is decreased

# %%
# early stop
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=20)
model.fit(X_train, y_train, epochs=100, 
            validation_data=(X_test, y_test), 
            callbacks=[early_stop])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0310 - accuracy: 0.9956 - val_loss: 0.1590 - val_accuracy: 0.9649
# Epoch 2/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 0.9912 - val_loss: 0.1487 - val_accuracy: 0.9561
# Epoch 3/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0279 - accuracy: 0.9890 - val_loss: 0.1524 - val_accuracy: 0.9561
# Epoch 4/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0268 - accuracy: 0.9934 - val_loss: 0.1505 - val_accuracy: 0.9561
# Epoch 5/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9956 - val_loss: 0.1499 - val_accuracy: 0.9561
# Epoch 6/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0270 - accuracy: 0.9934 - val_loss: 0.1509 - val_accuracy: 0.9561
# Epoch 7/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0272 - accuracy: 0.9868 - val_loss: 0.1567 - val_accuracy: 0.9649
# Epoch 8/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0258 - accuracy: 0.9912 - val_loss: 0.1510 - val_accuracy: 0.9561
# Epoch 9/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0268 - accuracy: 0.9890 - val_loss: 0.1512 - val_accuracy: 0.9561
# Epoch 10/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0266 - accuracy: 0.9890 - val_loss: 0.1572 - val_accuracy: 0.9561
# Epoch 11/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0254 - accuracy: 0.9956 - val_loss: 0.1536 - val_accuracy: 0.9561
# Epoch 12/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0246 - accuracy: 0.9934 - val_loss: 0.1556 - val_accuracy: 0.9561
# Epoch 13/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9956 - val_loss: 0.1548 - val_accuracy: 0.9561
# Epoch 14/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0253 - accuracy: 0.9956 - val_loss: 0.1556 - val_accuracy: 0.9561
# Epoch 15/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0244 - accuracy: 0.9934 - val_loss: 0.1541 - val_accuracy: 0.9561
# Epoch 16/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0237 - accuracy: 0.9934 - val_loss: 0.1570 - val_accuracy: 0.9561
# Epoch 17/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0248 - accuracy: 0.9890 - val_loss: 0.1531 - val_accuracy: 0.9561
# Epoch 18/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0241 - accuracy: 0.9934 - val_loss: 0.1628 - val_accuracy: 0.9561
# Epoch 19/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0293 - accuracy: 0.9868 - val_loss: 0.1560 - val_accuracy: 0.9561
# Epoch 20/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0230 - accuracy: 0.9956 - val_loss: 0.1559 - val_accuracy: 0.9561
# Epoch 21/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0231 - accuracy: 0.9956 - val_loss: 0.1558 - val_accuracy: 0.9561
# Epoch 22/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0251 - accuracy: 0.9912 - val_loss: 0.1547 - val_accuracy: 0.9561

# %% [markdown]
# SAVE THE MODEL

# %%
#save model
model.save('BC_model.h5')

# %% [markdown]
# SAVE THE SCALER

# %%
import pickle
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %%
import tensorflow as tf
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import warnings

warnings.filterwarnings("ignore")

# Load the model
model = tf.keras.models.load_model('BC_model.h5')

# load scalar parameters
# Load fitted scaler
with open("scaler.pkl", "rb") as f:
    scaler = pickle.load(f)


# Example input data (replace with your own data)
# Ensure you include all 30 features expected by the model
input_data = {
    'radius_mean': [14.0],
    'texture_mean': [20.0],
    'perimeter_mean': [90.0],
    'area_mean': [600.0],
    'smoothness_mean': [0.1],
    'compactness_mean': [0.15],
    'concavity_mean': [0.2],
    'concave points_mean': [0.1],   # FIXED
    'symmetry_mean': [0.2],
    'fractal_dimension_mean': [0.06],

    'radius_se': [0.2],
    'texture_se': [1.0],
    'perimeter_se': [1.5],
    'area_se': [20.0],
    'smoothness_se': [0.005],
    'compactness_se': [0.02],
    'concavity_se': [0.03],
    'concave points_se': [0.01],    # FIXED
    'symmetry_se': [0.03],
    'fractal_dimension_se': [0.004],

    'radius_worst': [16.0],
    'texture_worst': [25.0],
    'perimeter_worst': [105.0],
    'area_worst': [800.0],
    'smoothness_worst': [0.12],
    'compactness_worst': [0.2],
    'concavity_worst': [0.3],
    'concave points_worst': [0.15], # FIXED
    'symmetry_worst': [0.25],
    'fractal_dimension_worst': [0.08]
}


# Convert to DataFrame
input_df = pd.DataFrame(input_data)

# Preprocess the input data (normalize, scale, etc.)
input_array = scaler.transform(input_df)  # Directly use the transformed array

# Make predictions
predictions = model.predict(input_array)

# For binary classification, convert probabilities to class labels
predicted_classes = (predictions > 0.5).astype("int32")  # Assuming a threshold of 0.5

# # Example mapping for binary classification
class_mapping = {0: 'Benign', 1: 'Malignant'}

# List comprehension to map predicted class labels to their corresponding names
predicted_class_names = []
for label in predicted_classes:
    predicted_class_names.append(class_mapping[label[0]])


print(predicted_class_names)
# Out:
# 1/1 [==============================] - 0s 118ms/step
# ['Malignant']
