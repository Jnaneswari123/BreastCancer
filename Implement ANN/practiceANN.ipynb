# %%
print("Hello")
# Out:
# Hello

# %%
# import liberaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("breast-cancer-wisconsin.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
#remove Id and unnamed columns
df = df.drop(columns = ['id','Unnamed: 32'])
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
sns.countplot(x='diagnosis', data=df)
plt.show()

# %%
# new colum for benign and malign
df['benign_0__mal_1'] = 0
df.loc[df['diagnosis']=='M', 'benign_0__mal_1'] = 1

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0         0.2419  ...          17.33           184.60      2019.0
# 1         0.1812  ...          23.41           158.80      1956.0
# 2         0.2069  ...          25.53           152.50      1709.0
# 3         0.2597  ...          26.50            98.87       567.7
# 4         0.1809  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  benign_0__mal_1
# 0          0.4601                  0.11890                1
# 1          0.2750                  0.08902                1
# 2          0.3613                  0.08758                1
# 3          0.6638                  0.17300                1
# 4          0.2364                  0.07678                1
#
# [5 rows x 32 columns]

# %%
sns.countplot(x='benign_0__mal_1', data=df)
plt.show()

# %%
# drop Diagnosis
df = df.drop(columns = ['diagnosis'])
df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  benign_0__mal_1
# 0          0.4601                  0.11890                1
# 1          0.2750                  0.08902                1
# 2          0.3613                  0.08758                1
# 3          0.6638                  0.17300                1
# 4          0.2364                  0.07678                1
#
# [5 rows x 31 columns]

# %%
df.shape
# Out:
# (569, 31)

# %%
# independent and dependent

X = df.drop(['benign_0__mal_1'], axis=1)
y = df['benign_0__mal_1']

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: benign_0__mal_1, dtype: int64

# %%
X.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal_dimension_mean  ...  radius_worst  \
# count     569.000000              569.000000  ...    569.000000
# mean        0.181162                0.062798  ...     16.269190
# std         0.027414                0.007060  ...      4.833242
# min         0.106000                0.049960  ...      7.930000
# 25%         0.161900                0.057700  ...     13.010000
# 50%         0.179200                0.061540  ...     14.970000
# 75%         0.195700                0.066120  ...     18.790000
# max         0.304000                0.097440  ...     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        symmetry_worst  fractal_dimension_worst
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
#apply min max scaler

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X)
X = scaler.fit_transform(X)
X = pd.DataFrame(X)
X.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.521037  0.022658  0.545989  0.363733  0.593753  0.792037  0.703140
# 1  0.643144  0.272574  0.615783  0.501591  0.289880  0.181768  0.203608
# 2  0.601496  0.390260  0.595743  0.449417  0.514309  0.431017  0.462512
# 3  0.210090  0.360839  0.233501  0.102906  0.811321  0.811361  0.565604
# 4  0.629893  0.156578  0.630986  0.489290  0.430351  0.347893  0.463918
#
#          7         8         9   ...        20        21        22        23  \
# 0  0.731113  0.686364  0.605518  ...  0.620776  0.141525  0.668310  0.450698
# 1  0.348757  0.379798  0.141323  ...  0.606901  0.303571  0.539818  0.435214
# 2  0.635686  0.509596  0.211247  ...  0.556386  0.360075  0.508442  0.374508
# 3  0.522863  0.776263  1.000000  ...  0.248310  0.385928  0.241347  0.094008
# 4  0.518390  0.378283  0.186816  ...  0.519744  0.123934  0.506948  0.341575
#
#          24        25        26        27        28        29
# 0  0.601136  0.619292  0.568610  0.912027  0.598462  0.418864
# 1  0.347553  0.154563  0.192971  0.639175  0.233590  0.222878
# 2  0.483590  0.385375  0.359744  0.835052  0.403706  0.213433
# 3  0.915472  0.814012  0.548642  0.884880  1.000000  0.773711
# 4  0.437364  0.172415  0.319489  0.558419  0.157500  0.142595
#
# [5 rows x 30 columns]

# %%
# train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (455, 30)
# (114, 30)
# (455,)
# (114,)

# %%
# ann with sklearn
from sklearn.neural_network import MLPClassifier
model = MLPClassifier(hidden_layer_sizes=(10,10), max_iter=100)
model.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(10, 10), max_iter=100)

# %%
model.score(X_test, y_test)
# Out:
# 0.9298245614035088

# %%
# build ANN with tensorflow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import InputLayer

# %%
model = Sequential()
model.add(InputLayer(input_shape=(30,))) # input layer
model.add(Dense(10, activation='relu')) # hidden layer 1
model.add(Dense(5, activation='relu')) # hidden layer 2
model.add(Dense(1, activation='sigmoid')) # output layer

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 10)                310
#
#  dense_9 (Dense)             (None, 5)                 55
#
#  dense_10 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 371 (1.45 KB)
# Trainable params: 371 (1.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy',
                 metrics=['accuracy'])
model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 19ms/step - loss: 0.7244 - accuracy: 0.6484 - val_loss: 0.7525 - val_accuracy: 0.5439
# Epoch 2/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6973 - accuracy: 0.6484 - val_loss: 0.7186 - val_accuracy: 0.5439
# Epoch 3/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6689 - accuracy: 0.6484 - val_loss: 0.6803 - val_accuracy: 0.5439
# Epoch 4/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6248 - accuracy: 0.6484 - val_loss: 0.6535 - val_accuracy: 0.5439
# Epoch 5/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5825 - accuracy: 0.6484 - val_loss: 0.6198 - val_accuracy: 0.5439
# Epoch 6/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5518 - accuracy: 0.6484 - val_loss: 0.5969 - val_accuracy: 0.5439
# Epoch 7/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5256 - accuracy: 0.6484 - val_loss: 0.5743 - val_accuracy: 0.5439
# Epoch 8/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5040 - accuracy: 0.6484 - val_loss: 0.5573 - val_accuracy: 0.5439
# Epoch 9/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4860 - accuracy: 0.6484 - val_loss: 0.5411 - val_accuracy: 0.5439
# Epoch 10/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.4705 - accuracy: 0.6484 - val_loss: 0.5221 - val_accuracy: 0.5439
# Epoch 11/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4556 - accuracy: 0.6484 - val_loss: 0.5121 - val_accuracy: 0.5439
# Epoch 12/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4437 - accuracy: 0.6484 - val_loss: 0.5022 - val_accuracy: 0.5439
# Epoch 13/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.4318 - accuracy: 0.8330 - val_loss: 0.4857 - val_accuracy: 0.8070
# Epoch 14/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4212 - accuracy: 0.8462 - val_loss: 0.4776 - val_accuracy: 0.8246
# Epoch 15/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4117 - accuracy: 0.8571 - val_loss: 0.4613 - val_accuracy: 0.8333
# Epoch 16/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4034 - accuracy: 0.8835 - val_loss: 0.4522 - val_accuracy: 0.8333
# Epoch 17/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3923 - accuracy: 0.8681 - val_loss: 0.4512 - val_accuracy: 0.8333
# Epoch 18/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3839 - accuracy: 0.8901 - val_loss: 0.4335 - val_accuracy: 0.8596
# Epoch 19/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3770 - accuracy: 0.9055 - val_loss: 0.4283 - val_accuracy: 0.8596
# Epoch 20/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3701 - accuracy: 0.8967 - val_loss: 0.4227 - val_accuracy: 0.8684
# Epoch 21/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3626 - accuracy: 0.9077 - val_loss: 0.4128 - val_accuracy: 0.8684
# Epoch 22/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3556 - accuracy: 0.9099 - val_loss: 0.4096 - val_accuracy: 0.8684
# Epoch 23/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3492 - accuracy: 0.9209 - val_loss: 0.4015 - val_accuracy: 0.8684
# Epoch 24/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3430 - accuracy: 0.9209 - val_loss: 0.3982 - val_accuracy: 0.8684
# Epoch 25/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3383 - accuracy: 0.9209 - val_loss: 0.3881 - val_accuracy: 0.8860
# Epoch 26/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3333 - accuracy: 0.9319 - val_loss: 0.3839 - val_accuracy: 0.8860
# Epoch 27/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3289 - accuracy: 0.9231 - val_loss: 0.3835 - val_accuracy: 0.8772
# Epoch 28/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3235 - accuracy: 0.9319 - val_loss: 0.3701 - val_accuracy: 0.9035
# Epoch 29/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3177 - accuracy: 0.9275 - val_loss: 0.3727 - val_accuracy: 0.8860
# Epoch 30/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3126 - accuracy: 0.9297 - val_loss: 0.3636 - val_accuracy: 0.9035
# Epoch 31/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3074 - accuracy: 0.9363 - val_loss: 0.3541 - val_accuracy: 0.9123
# Epoch 32/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3049 - accuracy: 0.9407 - val_loss: 0.3493 - val_accuracy: 0.9123
# Epoch 33/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.3013 - accuracy: 0.9407 - val_loss: 0.3452 - val_accuracy: 0.9123
# Epoch 34/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2961 - accuracy: 0.9363 - val_loss: 0.3522 - val_accuracy: 0.9035
# Epoch 35/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2918 - accuracy: 0.9429 - val_loss: 0.3372 - val_accuracy: 0.9211
# Epoch 36/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2870 - accuracy: 0.9451 - val_loss: 0.3352 - val_accuracy: 0.9123
# Epoch 37/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2837 - accuracy: 0.9429 - val_loss: 0.3346 - val_accuracy: 0.9123
# Epoch 38/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2800 - accuracy: 0.9429 - val_loss: 0.3291 - val_accuracy: 0.9123
# Epoch 39/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2780 - accuracy: 0.9495 - val_loss: 0.3204 - val_accuracy: 0.9649
# Epoch 40/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2727 - accuracy: 0.9473 - val_loss: 0.3229 - val_accuracy: 0.9123
# Epoch 41/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2702 - accuracy: 0.9451 - val_loss: 0.3150 - val_accuracy: 0.9474
# Epoch 42/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2660 - accuracy: 0.9429 - val_loss: 0.3108 - val_accuracy: 0.9561
# Epoch 43/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2621 - accuracy: 0.9451 - val_loss: 0.3100 - val_accuracy: 0.9386
# Epoch 44/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2595 - accuracy: 0.9473 - val_loss: 0.3043 - val_accuracy: 0.9649
# Epoch 45/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2564 - accuracy: 0.9516 - val_loss: 0.3040 - val_accuracy: 0.9474
# Epoch 46/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2545 - accuracy: 0.9429 - val_loss: 0.2998 - val_accuracy: 0.9561
# Epoch 47/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2509 - accuracy: 0.9473 - val_loss: 0.2952 - val_accuracy: 0.9737
# Epoch 48/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2469 - accuracy: 0.9516 - val_loss: 0.2938 - val_accuracy: 0.9561
# Epoch 49/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2446 - accuracy: 0.9516 - val_loss: 0.2895 - val_accuracy: 0.9649
# Epoch 50/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2421 - accuracy: 0.9516 - val_loss: 0.2868 - val_accuracy: 0.9649
# Epoch 51/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2396 - accuracy: 0.9582 - val_loss: 0.2819 - val_accuracy: 0.9737
# Epoch 52/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.2365 - accuracy: 0.9516 - val_loss: 0.2709 - val_accuracy: 0.9737
# Epoch 53/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.2153 - accuracy: 0.9604 - val_loss: 0.2342 - val_accuracy: 0.9737
# Epoch 54/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.1905 - accuracy: 0.9604 - val_loss: 0.2043 - val_accuracy: 0.9737
# Epoch 55/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1669 - accuracy: 0.9670 - val_loss: 0.1754 - val_accuracy: 0.9737
# Epoch 56/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1484 - accuracy: 0.9648 - val_loss: 0.1619 - val_accuracy: 0.9737
# Epoch 57/100
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1387 - accuracy: 0.9582 - val_loss: 0.1436 - val_accuracy: 0.9737
# Epoch 58/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9692 - val_loss: 0.1364 - val_accuracy: 0.9737
# Epoch 59/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1210 - accuracy: 0.9582 - val_loss: 0.1327 - val_accuracy: 0.9737
# Epoch 60/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.1125 - accuracy: 0.9758 - val_loss: 0.1219 - val_accuracy: 0.9737
# Epoch 61/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1072 - accuracy: 0.9692 - val_loss: 0.1211 - val_accuracy: 0.9825
# Epoch 62/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1035 - accuracy: 0.9780 - val_loss: 0.1137 - val_accuracy: 0.9737
# Epoch 63/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1013 - accuracy: 0.9692 - val_loss: 0.1137 - val_accuracy: 0.9737
# Epoch 64/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0977 - accuracy: 0.9714 - val_loss: 0.1105 - val_accuracy: 0.9737
# Epoch 65/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0959 - accuracy: 0.9736 - val_loss: 0.1099 - val_accuracy: 0.9825
# Epoch 66/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0932 - accuracy: 0.9714 - val_loss: 0.1054 - val_accuracy: 0.9737
# Epoch 67/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0911 - accuracy: 0.9758 - val_loss: 0.1028 - val_accuracy: 0.9737
# Epoch 68/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0896 - accuracy: 0.9758 - val_loss: 0.1030 - val_accuracy: 0.9737
# Epoch 69/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0875 - accuracy: 0.9758 - val_loss: 0.1075 - val_accuracy: 0.9737
# Epoch 70/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0886 - accuracy: 0.9692 - val_loss: 0.0992 - val_accuracy: 0.9737
# Epoch 71/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0861 - accuracy: 0.9758 - val_loss: 0.0997 - val_accuracy: 0.9737
# Epoch 72/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0842 - accuracy: 0.9758 - val_loss: 0.0983 - val_accuracy: 0.9737
# Epoch 73/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0828 - accuracy: 0.9802 - val_loss: 0.0944 - val_accuracy: 0.9737
# Epoch 74/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0811 - accuracy: 0.9846 - val_loss: 0.0987 - val_accuracy: 0.9649
# Epoch 75/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0806 - accuracy: 0.9824 - val_loss: 0.0907 - val_accuracy: 0.9825
# Epoch 76/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0806 - accuracy: 0.9802 - val_loss: 0.1018 - val_accuracy: 0.9737
# Epoch 77/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0786 - accuracy: 0.9780 - val_loss: 0.0919 - val_accuracy: 0.9737
# Epoch 78/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0788 - accuracy: 0.9780 - val_loss: 0.0915 - val_accuracy: 0.9737
# Epoch 79/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0855 - accuracy: 0.9714 - val_loss: 0.0890 - val_accuracy: 0.9737
# Epoch 80/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0756 - accuracy: 0.9824 - val_loss: 0.0918 - val_accuracy: 0.9737
# Epoch 81/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0746 - accuracy: 0.9802 - val_loss: 0.0933 - val_accuracy: 0.9825
# Epoch 82/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0743 - accuracy: 0.9758 - val_loss: 0.0961 - val_accuracy: 0.9737
# Epoch 83/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0723 - accuracy: 0.9780 - val_loss: 0.0886 - val_accuracy: 0.9737
# Epoch 84/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0733 - accuracy: 0.9758 - val_loss: 0.0924 - val_accuracy: 0.9825
# Epoch 85/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0722 - accuracy: 0.9758 - val_loss: 0.0876 - val_accuracy: 0.9737
# Epoch 86/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0734 - accuracy: 0.9758 - val_loss: 0.0876 - val_accuracy: 0.9737
# Epoch 87/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0720 - accuracy: 0.9780 - val_loss: 0.0897 - val_accuracy: 0.9737
# Epoch 88/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0716 - accuracy: 0.9758 - val_loss: 0.0906 - val_accuracy: 0.9825
# Epoch 89/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0688 - accuracy: 0.9780 - val_loss: 0.0845 - val_accuracy: 0.9825
# Epoch 90/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0693 - accuracy: 0.9824 - val_loss: 0.0910 - val_accuracy: 0.9737
# Epoch 91/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0672 - accuracy: 0.9846 - val_loss: 0.0863 - val_accuracy: 0.9825
# Epoch 92/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0665 - accuracy: 0.9846 - val_loss: 0.0875 - val_accuracy: 0.9737
# Epoch 93/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0673 - accuracy: 0.9824 - val_loss: 0.0908 - val_accuracy: 0.9737
# Epoch 94/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0656 - accuracy: 0.9802 - val_loss: 0.0862 - val_accuracy: 0.9825
# Epoch 95/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0671 - accuracy: 0.9802 - val_loss: 0.0880 - val_accuracy: 0.9649
# Epoch 96/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0665 - accuracy: 0.9780 - val_loss: 0.0910 - val_accuracy: 0.9737
# Epoch 97/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0638 - accuracy: 0.9824 - val_loss: 0.0844 - val_accuracy: 0.9825
# Epoch 98/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0636 - accuracy: 0.9824 - val_loss: 0.0877 - val_accuracy: 0.9737
# Epoch 99/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0659 - accuracy: 0.9802 - val_loss: 0.0872 - val_accuracy: 0.9825
# Epoch 100/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0645 - accuracy: 0.9758 - val_loss: 0.0930 - val_accuracy: 0.9737

# %%
# plot train and test accuracy
import matplotlib.pyplot as plt
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
plt.show()

# %%
# early stop
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=20)
model.fit(X_train, y_train, epochs=100, 
            validation_data=(X_test, y_test), 
            callbacks=[early_stop])
# Out:
# Epoch 1/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.0490 - accuracy: 0.9868 - val_loss: 0.0666 - val_accuracy: 0.9825
# Epoch 2/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0490 - accuracy: 0.9890 - val_loss: 0.0665 - val_accuracy: 0.9737
# Epoch 3/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0484 - accuracy: 0.9868 - val_loss: 0.0668 - val_accuracy: 0.9737
# Epoch 4/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0481 - accuracy: 0.9868 - val_loss: 0.0668 - val_accuracy: 0.9737
# Epoch 5/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0477 - accuracy: 0.9890 - val_loss: 0.0668 - val_accuracy: 0.9649
# Epoch 6/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0483 - accuracy: 0.9868 - val_loss: 0.0669 - val_accuracy: 0.9737
# Epoch 7/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0478 - accuracy: 0.9868 - val_loss: 0.0679 - val_accuracy: 0.9825
# Epoch 8/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0480 - accuracy: 0.9890 - val_loss: 0.0662 - val_accuracy: 0.9649
# Epoch 9/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0499 - accuracy: 0.9846 - val_loss: 0.0670 - val_accuracy: 0.9649
# Epoch 10/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 0.9846 - val_loss: 0.0667 - val_accuracy: 0.9737
# Epoch 11/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0474 - accuracy: 0.9890 - val_loss: 0.0665 - val_accuracy: 0.9737
# Epoch 12/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0472 - accuracy: 0.9890 - val_loss: 0.0669 - val_accuracy: 0.9737
# Epoch 13/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0480 - accuracy: 0.9868 - val_loss: 0.0668 - val_accuracy: 0.9737
# Epoch 14/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0481 - accuracy: 0.9846 - val_loss: 0.0668 - val_accuracy: 0.9649
# Epoch 15/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0472 - accuracy: 0.9890 - val_loss: 0.0677 - val_accuracy: 0.9825
# Epoch 16/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0482 - accuracy: 0.9890 - val_loss: 0.0668 - val_accuracy: 0.9737
# Epoch 17/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0479 - accuracy: 0.9912 - val_loss: 0.0674 - val_accuracy: 0.9825
# Epoch 18/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0469 - accuracy: 0.9890 - val_loss: 0.0670 - val_accuracy: 0.9649
# Epoch 19/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.0478 - accuracy: 0.9868 - val_loss: 0.0669 - val_accuracy: 0.9737
# Epoch 20/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0469 - accuracy: 0.9890 - val_loss: 0.0676 - val_accuracy: 0.9649
# Epoch 21/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0475 - accuracy: 0.9868 - val_loss: 0.0674 - val_accuracy: 0.9737
# Epoch 22/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0473 - accuracy: 0.9890 - val_loss: 0.0678 - val_accuracy: 0.9737
# Epoch 23/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0465 - accuracy: 0.9890 - val_loss: 0.0673 - val_accuracy: 0.9649
# Epoch 24/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.9868 - val_loss: 0.0672 - val_accuracy: 0.9649
# Epoch 25/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0493 - accuracy: 0.9868 - val_loss: 0.0667 - val_accuracy: 0.9649
# Epoch 26/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.9890 - val_loss: 0.0665 - val_accuracy: 0.9737
# Epoch 27/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0474 - accuracy: 0.9868 - val_loss: 0.0668 - val_accuracy: 0.9737
# Epoch 28/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0478 - accuracy: 0.9846 - val_loss: 0.0664 - val_accuracy: 0.9649

# %%
# plot train and test accuracy
import matplotlib.pyplot as plt
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
plt.show()

# %%
# save model
model.save('BC_model.h5')

# %%
# save scalar parameters
import pickle
with open("BC_scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

# %% [markdown]
# # for predictions on new input

# %%
import streamlit as st
import tensorflow as tf
import pandas as pd
import pickle
import warnings

warnings.filterwarnings("ignore")

# -------------------------------
# Page config
# -------------------------------
st.set_page_config(
    page_title="Breast Cancer Prediction",
    layout="centered"
)

st.title("Breast Cancer Prediction")
st.write("Enter the tumor feature values and predict the class.")

# -------------------------------
# Load model & scaler (once)
# -------------------------------
@st.cache_resource
def load_artifacts():
    model = tf.keras.models.load_model("BC_model.h5")
    with open("BC_scaler.pkl", "rb") as f:
        scaler = pickle.load(f)
    return model, scaler

model, scaler = load_artifacts()

# -------------------------------
# Input fields (EXACT feature names)
# -------------------------------
st.subheader("Input Features")

input_data = {
    'radius_mean': st.number_input('radius_mean', value=14.0),
    'texture_mean': st.number_input('texture_mean', value=20.0),
    'perimeter_mean': st.number_input('perimeter_mean', value=90.0),
    'area_mean': st.number_input('area_mean', value=600.0),
    'smoothness_mean': st.number_input('smoothness_mean', value=0.1),
    'compactness_mean': st.number_input('compactness_mean', value=0.15),
    'concavity_mean': st.number_input('concavity_mean', value=0.2),
    'concave points_mean': st.number_input('concave points_mean', value=0.1),
    'symmetry_mean': st.number_input('symmetry_mean', value=0.2),
    'fractal_dimension_mean': st.number_input('fractal_dimension_mean', value=0.06),

    'radius_se': st.number_input('radius_se', value=0.2),
    'texture_se': st.number_input('texture_se', value=1.0),
    'perimeter_se': st.number_input('perimeter_se', value=1.5),
    'area_se': st.number_input('area_se', value=20.0),
    'smoothness_se': st.number_input('smoothness_se', value=0.005),
    'compactness_se': st.number_input('compactness_se', value=0.02),
    'concavity_se': st.number_input('concavity_se', value=0.03),
    'concave points_se': st.number_input('concave points_se', value=0.01),
    'symmetry_se': st.number_input('symmetry_se', value=0.03),
    'fractal_dimension_se': st.number_input('fractal_dimension_se', value=0.004),

    'radius_worst': st.number_input('radius_worst', value=16.0),
    'texture_worst': st.number_input('texture_worst', value=25.0),
    'perimeter_worst': st.number_input('perimeter_worst', value=105.0),
    'area_worst': st.number_input('area_worst', value=800.0),
    'smoothness_worst': st.number_input('smoothness_worst', value=0.12),
    'compactness_worst': st.number_input('compactness_worst', value=0.2),
    'concavity_worst': st.number_input('concavity_worst', value=0.3),
    'concave points_worst': st.number_input('concave points_worst', value=0.15),
    'symmetry_worst': st.number_input('symmetry_worst', value=0.25),
    'fractal_dimension_worst': st.number_input('fractal_dimension_worst', value=0.08),
}

# -------------------------------
# Prediction
# -------------------------------
if st.button("Predict"):
    input_df = pd.DataFrame([input_data])

    # Safety check — do NOT remove
    if list(input_df.columns) != list(scaler.feature_names_in_):
        st.error("Feature mismatch between input and trained scaler.")
        st.stop()

    input_scaled = scaler.transform(input_df)
    prediction = model.predict(input_scaled)[0][0]

    predicted_class = "Malignant" if prediction > 0.5 else "Benign"

    st.subheader("Result")
    st.write(f"**Prediction:** {predicted_class}")
    st.write(f"**Probability:** {prediction:.4f}")
# Out:
# 1/1 [==============================] - 1s 709ms/step
# ['Malignant']
